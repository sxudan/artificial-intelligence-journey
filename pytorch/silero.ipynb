# %%
import torch

# %%
language = 'en'
model_id = 'v3_en'
sample_rate = 48000
speaker = 'baya_v2'
device = torch.device('cpu')

# model, decoder, utils = torch.hub.load(repo_or_dir='snakers4/silero-models', model='silero_stt', language=language)

model, example_text = torch.hub.load(repo_or_dir='snakers4/silero-models',
                                     model='silero_tts',
                                     language=language,
                                     speaker=model_id
                                     )
# Out:
# Using cache found in /Users/xkal/.cache/torch/hub/snakers4_silero-models_master
# 100%|██████████| 54.5M/54.5M [00:09<00:00, 6.20MB/s]

# %%
print(model)
# Out:
# <<torch_package_1>.multi_acc_v3_package.TTSModelMultiAcc_v3 object at 0x1663e5100>

# %%
model.to(device)  # gpu or cpu

# %%
print(example_text)
# Out:
# Can you can a canned can into an un-canned can like a canner can can a canned can into an un-canned can?

# %%
audio = model.apply_tts(text="The difference between a normal spectrogram and a Mel spectrogram lies in how they represent the frequency content of an audio signal. Here's a comparison:",
                        speaker='en_2',
                        sample_rate=sample_rate)

# %%
import IPython
import IPython.display

IPython.display.Audio(audio, rate=44100)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
device = torch.device('cpu')
model, decoder, utils = torch.hub.load(repo_or_dir='snakers4/silero-models',
                                       model='silero_stt',
                                       language='en', # also available 'de', 'es'
                                       device=device)
# Out:
# /usr/local/lib/python3.8/site-packages/torch/hub.py:286: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/snakers4/silero-models/zipball/master" to /Users/xkal/.cache/torch/hub/master.zip
# 100%|██████████| 112M/112M [00:15<00:00, 7.59MB/s]

# %%
import torchaudio
from glob import glob

(read_batch, split_into_batches,
 read_audio, prepare_model_input) = utils  # see function signature for details

# download a single file, any format compatible with TorchAudio (soundfile backend)
# torch.hub.download_url_to_file('https://opus-codec.org/static/examples/samples/speech_orig.wav',
#                                dst ='speech_orig.wav', progress=True)
# Out:
# 100%|██████████| 0.99M/0.99M [00:01<00:00, 660kB/s]

# %%
test_files = glob('audio.wav')
batches = split_into_batches(test_files, batch_size=10)
input = prepare_model_input(read_batch(batches[0]),
                            device=device)

output = model(input)
for example in output:
    print(example.shape)
    print(decoder(example.cpu()))
# Out:
# torch.Size([36, 999])
# screw you guys i am going home

# %%
text = decoder(output[0].cpu())
# Out:
# 'screw you guys i am going home'
